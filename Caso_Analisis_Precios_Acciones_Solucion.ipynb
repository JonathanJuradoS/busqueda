# %% [markdown]
# <a href="https://colab.research.google.com/github/JonathanJuradoS/busqueda/blob/main/Caso_Analisis_Precios_Acciones_Solucion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📈 Caso Práctico: Análisis de Precios de Acciones
#
# ## 🧩 Contexto:
# En el ámbito financiero, las empresas y los inversores monitorean constantemente la evolución del precio de sus acciones para tomar decisiones estratégicas de compra y venta. El análisis técnico se basa en patrones de comportamiento del mercado, y uno de los puntos clave es la identificación de **máximos y mínimos locales** en series temporales.
#
# Este caso simula el análisis de los precios diarios de una acción durante 60 días consecutivos. A través de los algoritmos de detección de extremos locales, se busca identificar:
# - **Zonas de compra (mínimos locales)**: donde el precio ha descendido respecto a sus días vecinos.
# - **Zonas de venta (máximos locales)**: donde el precio ha alcanzado un pico en comparación con sus días cercanos.
#
# El análisis se complementará con visualizaciones para facilitar la interpretación de los resultados.
#
# ---
#
# ## 🎯 Objetivo:
# 1. Cargar y explorar datos reales simulados desde un archivo CSV.
# 2. Visualizar la evolución temporal de los precios.
# 3. Aplicar lógica de búsqueda local para encontrar máximos y mínimos.
# 4. Marcar gráficamente los puntos estratégicos de compra y venta.
# 5. Reflexionar sobre el uso de IA en decisiones de inversión.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el dataset
df = pd.read_csv("/content/Dataset_Precios_Acciones.csv", parse_dates=["Fecha"])
df.head()
# Out:
#        Fecha  Precio
# 0 2024-01-01  101.49
# 1 2024-01-02  101.72
# 2 2024-01-03  103.51
# 3 2024-01-04  107.06
# 4 2024-01-05  107.09

# %%
# Visualizar evolución de precios
plt.figure(figsize=(12,6))
plt.plot(df["Fecha"], df["Precio"], label='Precio de la Acción', color='blue')
plt.title("Evolución del Precio de la Acción")
plt.xlabel("Fecha")
plt.ylabel("Precio")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Detectar máximos y mínimos locales
def detectar_extremos(precios):
    maximos = []
    minimos = []
    for i in range(1, len(precios)-1):
        if precios[i] > precios[i-1] and precios[i] > precios[i+1]:
            maximos.append(i)
        elif precios[i] < precios[i-1] and precios[i] < precios[i+1]:
            minimos.append(i)
    return maximos, minimos

maximos, minimos = detectar_extremos(df["Precio"].values)
print("Máximos encontrados:", len(maximos))
print("Mínimos encontrados:", len(minimos))
# Out:
# Máximos encontrados: 14
# Mínimos encontrados: 14

# %%
plt.figure(figsize=(12,6))
plt.plot(df["Fecha"], df["Precio"], label='Precio', color='blue')
plt.scatter(df["Fecha"].iloc[maximos], df["Precio"].iloc[maximos], color='red', label='Máximos')
plt.scatter(df["Fecha"].iloc[minimos], df["Precio"].iloc[minimos], color='green', label='Mínimos')
plt.title("Detección de Máximos y Mínimos Locales")
plt.xlabel("Fecha")
plt.ylabel("Precio")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## ✅ Conclusión
#
# A través del análisis de la curva de precios:
#
# - Se identificaron **picos locales** como posibles zonas de **venta**.
# - Se marcaron **valles locales** como posibles zonas de **compra**.
# - Esta técnica puede ser base para estrategias de inversión más complejas utilizando inteligencia artificial y predicción.
#
# Se recomienda complementar este análisis con indicadores técnicos, volumen de transacciones y análisis de tendencia.
